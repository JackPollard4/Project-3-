# %%
# Project-3-


import folium

# Define a dictionary with country names and their approximate latitude and longitude
country_coords = {
    "Uganda": [1.3733, 32.2903],
    "Tanzania": [-6.3690, 34.8888],
    "Serbia": [44.0165, 21.0059],
    "Senegal": [14.4974, -14.4524],
    "Panama": [8.5380, -80.7821],
    "Nigeria": [9.0820, 8.6753],
    "Mali": [17.5707, -3.9962],
    "Malawi": [-13.2543, 34.3015],
    "Guatemala": [15.7835, -90.2308],
    "Ghana": [7.9465, -1.0232],
    "Ethiopia": [9.1450, 40.4897]
}

# Create a map centered around Africa for better visibility
map_center = [10, 10]  
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the map
world_map



# Add USA coordinates to the dictionary
country_coords["USA"] = [37.0902, -95.7129]  # Approximate center of the USA

# Create a new map centered around Africa for better visibility
map_center = [10, 10]
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the updated map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a80bf48c996df9877dcc0374eb27f6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a80bf48c996df9877dcc0374eb27f6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a80bf48c996df9877dcc0374eb27f6d = L.map(
#                 &quot;map_6a80bf48c996df9877dcc0374eb27f6d&quot;,
#                 {
#                     center: [10.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33c8cfe7577ae08e0b5e7015783b92ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_33c8cfe7577ae08e0b5e7015783b92ce.addTo(map_6a80bf48c996df9877dcc0374eb27f6d);
#
#
#             var marker_600f6bfeb913cd767e57117734a588be = L.marker(
#                 [1.3733, 32.2903],
#                 {
# }
#             ).addTo(map_6a80bf48c996df9877dcc0374eb27f6d);
#
#
#             var icon_ca51d069d16104c3cdddda86db5ee162 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4307324936594aa48d21ddcf408a724c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d157c23575f9551c1e815c172b9f9b9 = $(`&lt;div id=&quot;html_8d157c23575f9551c1e815c172b9f9b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uganda&lt;/div&gt;`)[0];
#                 popup_4307324936594aa48d21ddcf408a724c.setContent(html_8d157c23575f9551c1e815c172b9f9b9);
#
#
#
#         marker_600f6bfeb913cd767e57117734a588be.bindPopup(popup_4307324936594aa48d21ddcf408a724c)
#         ;
#
#
#
#
#                 marker_600f6bfeb913cd767e57117734a588be.setIcon(icon_ca51d069d16104c3cdddda86db5ee162);
#
#
#             var marker_df464eda34ce71547212661e40b8ac1c = L.marker(
#                 [-6.369, 34.8888],
#                 {
# }
#             ).addTo(map_6a80bf48c996df9877dcc0374eb27f6d);
#
#
#             var icon_9fd7b340be3444bb036153a8fb3a970a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2c20a5bdaab713244f694742e6535c49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10b86e7bb33f759d0e9d184d4e886226 = $(`&lt;div id=&quot;html_10b86e7bb33f759d0e9d184d4e886226&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tanzania&lt;/div&gt;`)[0];
#                 popup_2c20a5bdaab713244f694742e6535c49.setContent(html_10b86e7bb33f759d0e9d184d4e886226);
#
#
#
#         marker_df464eda34ce71547212661e40b8ac1c.bindPopup(popup_2c20a5bdaab713244f694742e6535c49)
#         ;
#
#
#
#
#                 marker_df464eda34ce71547212661e40b8ac1c.setIcon(icon_9fd7b340be3444bb036153a8fb3a970a);
#
#
#             var marker_1d58111895e1096717a7f7a4ee9cff43 = L.marker(
#                 [44.0165, 21.0059],
#                 {
# }
#             ).addTo(map_6a80bf48c996df9877dcc0374eb27f6d);
#
#
#             var icon_3bca99b8aeb2ca856f5ea68b7e7fb413 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_dcddca6027877f54b8f15a45bc45e712 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8f0669a82be08b6f4a4f28be9a11003 = $(`&lt;div id=&quot;html_d8f0669a82be08b6f4a4f28be9a11003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Serbia&lt;/div&gt;`)[0];
#                 popup_dcddca6027877f54b8f15a45bc45e712.setContent(html_d8f0669a82be08b6f4a4f28be9a11003);
#
#
#
#         marker_1d58111895e1096717a7f7a4ee9cff43.bindPopup(popup_dcddca6027877f54b8f15a45bc45e712)
#         ;
#
#
#
#
#                 marker_1d58111895e1096717a7f7a4ee9cff43.setIcon(icon_3bca99b8aeb2ca856f5ea68b7e7fb413);
#
#
#             var marker_3626aa13398180ccbfb9bebaa67811cf = L.marker(
#                 [14.4974, -14.4524],
#                 {
# }
#             ).addTo(map_6a80bf48c996df9877dcc0374eb27f6d);
#
#
#             var icon_d05350e07f1c6f188735a7015bbe745a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quo
