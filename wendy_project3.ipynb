# %%
# Project-3-


import folium

# Define a dictionary with country names and their approximate latitude and longitude
country_coords = {
    "Uganda": [1.3733, 32.2903],
    "Tanzania": [-6.3690, 34.8888],
    "Serbia": [44.0165, 21.0059],
    "Senegal": [14.4974, -14.4524],
    "Panama": [8.5380, -80.7821],
    "Nigeria": [9.0820, 8.6753],
    "Mali": [17.5707, -3.9962],
    "Malawi": [-13.2543, 34.3015],
    "Guatemala": [15.7835, -90.2308],
    "Ghana": [7.9465, -1.0232],
    "Ethiopia": [9.1450, 40.4897]
}

# Create a map centered around Africa for better visibility
map_center = [10, 10]  
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the map
world_map



# Add USA coordinates to the dictionary
country_coords["USA"] = [37.0902, -95.7129]  # Approximate center of the USA

# Create a new map centered around Africa for better visibility
map_center = [10, 10]
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the updated map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbca4d33881d7c7d6afde943008dadc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbca4d33881d7c7d6afde943008dadc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbca4d33881d7c7d6afde943008dadc9 = L.map(
#                 &quot;map_fbca4d33881d7c7d6afde943008dadc9&quot;,
#                 {
#                     center: [10.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0356093d291a64e20654b8ae0e8ef6ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0356093d291a64e20654b8ae0e8ef6ec.addTo(map_fbca4d33881d7c7d6afde943008dadc9);
#
#
#             var marker_f6b810f378f2b1139941707a3517e464 = L.marker(
#                 [1.3733, 32.2903],
#                 {
# }
#             ).addTo(map_fbca4d33881d7c7d6afde943008dadc9);
#
#
#             var icon_752720c5544bc411e1f617ae69edfe7a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c671ad75a3f8f683a07a9611440dbfb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e88d4e998cfdd78721b3084a652a808 = $(`&lt;div id=&quot;html_4e88d4e998cfdd78721b3084a652a808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uganda&lt;/div&gt;`)[0];
#                 popup_c671ad75a3f8f683a07a9611440dbfb2.setContent(html_4e88d4e998cfdd78721b3084a652a808);
#
#
#
#         marker_f6b810f378f2b1139941707a3517e464.bindPopup(popup_c671ad75a3f8f683a07a9611440dbfb2)
#         ;
#
#
#
#
#                 marker_f6b810f378f2b1139941707a3517e464.setIcon(icon_752720c5544bc411e1f617ae69edfe7a);
#
#
#             var marker_b85a849f24c640656e1ef765ab801acc = L.marker(
#                 [-6.369, 34.8888],
#                 {
# }
#             ).addTo(map_fbca4d33881d7c7d6afde943008dadc9);
#
#
#             var icon_b80ad9e02463e98d219ce4ef1e991508 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6025c0d21cdda3965c2a402cc964f8a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_371f3c37962b46e15ff03e0b2e0e2ce5 = $(`&lt;div id=&quot;html_371f3c37962b46e15ff03e0b2e0e2ce5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tanzania&lt;/div&gt;`)[0];
#                 popup_6025c0d21cdda3965c2a402cc964f8a2.setContent(html_371f3c37962b46e15ff03e0b2e0e2ce5);
#
#
#
#         marker_b85a849f24c640656e1ef765ab801acc.bindPopup(popup_6025c0d21cdda3965c2a402cc964f8a2)
#         ;
#
#
#
#
#                 marker_b85a849f24c640656e1ef765ab801acc.setIcon(icon_b80ad9e02463e98d219ce4ef1e991508);
#
#
#             var marker_1c17a6d2e74e710ebd6d09c4d87dc2a1 = L.marker(
#                 [44.0165, 21.0059],
#                 {
# }
#             ).addTo(map_fbca4d33881d7c7d6afde943008dadc9);
#
#
#             var icon_f4ac097701495e5bc4add9bbceab1aa7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5d773bb2439eb81bb82aa87a410d9e22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31336447e56188ef65ac10450f5cb400 = $(`&lt;div id=&quot;html_31336447e56188ef65ac10450f5cb400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Serbia&lt;/div&gt;`)[0];
#                 popup_5d773bb2439eb81bb82aa87a410d9e22.setContent(html_31336447e56188ef65ac10450f5cb400);
#
#
#
#         marker_1c17a6d2e74e710ebd6d09c4d87dc2a1.bindPopup(popup_5d773bb2439eb81bb82aa87a410d9e22)
#         ;
#
#
#
#
#                 marker_1c17a6d2e74e710ebd6d09c4d87dc2a1.setIcon(icon_f4ac097701495e5bc4add9bbceab1aa7);
#
#
#             var marker_0a11b81ac284e1d271835806b764ab8e = L.marker(
#                 [14.4974, -14.4524],
#                 {
# }
#             ).addTo(map_fbca4d33881d7c7d6afde943008dadc9);
#
#
#             var icon_ff978c64e6b445cb6bea894b1974e50d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quo

# %%
# test
