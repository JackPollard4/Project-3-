# %%
# Project-3-


import folium

# Define a dictionary with country names and their approximate latitude and longitude
country_coords = {
    "Uganda": [1.3733, 32.2903],
    "Tanzania": [-6.3690, 34.8888],
    "Serbia": [44.0165, 21.0059],
    "Senegal": [14.4974, -14.4524],
    "Panama": [8.5380, -80.7821],
    "Nigeria": [9.0820, 8.6753],
    "Mali": [17.5707, -3.9962],
    "Malawi": [-13.2543, 34.3015],
    "Guatemala": [15.7835, -90.2308],
    "Ghana": [7.9465, -1.0232],
    "Ethiopia": [9.1450, 40.4897]
}

# Create a map centered around Africa for better visibility
map_center = [10, 10]  
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the map
world_map



# Add USA coordinates to the dictionary
country_coords["USA"] = [37.0902, -95.7129]  # Approximate center of the USA

# Create a new map centered around Africa for better visibility
map_center = [10, 10]
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the updated map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2149f5cd27cd65c57a11fa71553ca2f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2149f5cd27cd65c57a11fa71553ca2f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2149f5cd27cd65c57a11fa71553ca2f8 = L.map(
#                 &quot;map_2149f5cd27cd65c57a11fa71553ca2f8&quot;,
#                 {
#                     center: [10.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9af0fc470e8f5a00f32ecb6c99870b72 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9af0fc470e8f5a00f32ecb6c99870b72.addTo(map_2149f5cd27cd65c57a11fa71553ca2f8);
#
#
#             var marker_0f5f23d80d2612ac0f808e76a30f824b = L.marker(
#                 [1.3733, 32.2903],
#                 {
# }
#             ).addTo(map_2149f5cd27cd65c57a11fa71553ca2f8);
#
#
#             var icon_65f1bfef2728e782768dcae5699b270a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_724a286b8749746a486ff0b18ba2f38c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f64c2ec45874cf10830fe17ba8cdf5aa = $(`&lt;div id=&quot;html_f64c2ec45874cf10830fe17ba8cdf5aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uganda&lt;/div&gt;`)[0];
#                 popup_724a286b8749746a486ff0b18ba2f38c.setContent(html_f64c2ec45874cf10830fe17ba8cdf5aa);
#
#
#
#         marker_0f5f23d80d2612ac0f808e76a30f824b.bindPopup(popup_724a286b8749746a486ff0b18ba2f38c)
#         ;
#
#
#
#
#                 marker_0f5f23d80d2612ac0f808e76a30f824b.setIcon(icon_65f1bfef2728e782768dcae5699b270a);
#
#
#             var marker_0de7bf8294131309c9a6686b26839e40 = L.marker(
#                 [-6.369, 34.8888],
#                 {
# }
#             ).addTo(map_2149f5cd27cd65c57a11fa71553ca2f8);
#
#
#             var icon_4db7e4949ce41f02088805c732136e3c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3ccb11dd74220ee3d866bbe0c50d0516 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a98c15476274148caf806d5a65886d3 = $(`&lt;div id=&quot;html_3a98c15476274148caf806d5a65886d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tanzania&lt;/div&gt;`)[0];
#                 popup_3ccb11dd74220ee3d866bbe0c50d0516.setContent(html_3a98c15476274148caf806d5a65886d3);
#
#
#
#         marker_0de7bf8294131309c9a6686b26839e40.bindPopup(popup_3ccb11dd74220ee3d866bbe0c50d0516)
#         ;
#
#
#
#
#                 marker_0de7bf8294131309c9a6686b26839e40.setIcon(icon_4db7e4949ce41f02088805c732136e3c);
#
#
#             var marker_aa06bd2381d671304b05e27edd226a90 = L.marker(
#                 [44.0165, 21.0059],
#                 {
# }
#             ).addTo(map_2149f5cd27cd65c57a11fa71553ca2f8);
#
#
#             var icon_99d085a4134ac180af06ea0ca30709f5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ebb3fe7a10622561bd4b162c2881127c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86f477801624ae3255662dc669aa38fb = $(`&lt;div id=&quot;html_86f477801624ae3255662dc669aa38fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Serbia&lt;/div&gt;`)[0];
#                 popup_ebb3fe7a10622561bd4b162c2881127c.setContent(html_86f477801624ae3255662dc669aa38fb);
#
#
#
#         marker_aa06bd2381d671304b05e27edd226a90.bindPopup(popup_ebb3fe7a10622561bd4b162c2881127c)
#         ;
#
#
#
#
#                 marker_aa06bd2381d671304b05e27edd226a90.setIcon(icon_99d085a4134ac180af06ea0ca30709f5);
#
#
#             var marker_dc8736fc6b50b4e171f924d7d3fb2430 = L.marker(
#                 [14.4974, -14.4524],
#                 {
# }
#             ).addTo(map_2149f5cd27cd65c57a11fa71553ca2f8);
#
#
#             var icon_7286449d8d37a976da16ad6a5635f2b3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quo

# %%
#test
