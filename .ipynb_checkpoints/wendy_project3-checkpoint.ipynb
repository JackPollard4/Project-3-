# %%
# Project-3-


import folium

# Define a dictionary with country names and their approximate latitude and longitude
country_coords = {
    "Uganda": [1.3733, 32.2903],
    "Tanzania": [-6.3690, 34.8888],
    "Serbia": [44.0165, 21.0059],
    "Senegal": [14.4974, -14.4524],
    "Panama": [8.5380, -80.7821],
    "Nigeria": [9.0820, 8.6753],
    "Mali": [17.5707, -3.9962],
    "Malawi": [-13.2543, 34.3015],
    "Guatemala": [15.7835, -90.2308],
    "Ghana": [7.9465, -1.0232],
    "Ethiopia": [9.1450, 40.4897]
}

# Create a map centered around Africa for better visibility
map_center = [10, 10]  
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the map
world_map



# Add USA coordinates to the dictionary
country_coords["USA"] = [37.0902, -95.7129]  # Approximate center of the USA

# Create a new map centered around Africa for better visibility
map_center = [10, 10]
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the updated map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_658430d228264cbbb8d325a933a6f87c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_658430d228264cbbb8d325a933a6f87c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_658430d228264cbbb8d325a933a6f87c = L.map(
#                 &quot;map_658430d228264cbbb8d325a933a6f87c&quot;,
#                 {
#                     center: [10.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_101c8cf224d390a97124ec9baebf28f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_101c8cf224d390a97124ec9baebf28f5.addTo(map_658430d228264cbbb8d325a933a6f87c);
#
#
#             var marker_fead99248fc4d055ca508a3e2dd4dded = L.marker(
#                 [1.3733, 32.2903],
#                 {
# }
#             ).addTo(map_658430d228264cbbb8d325a933a6f87c);
#
#
#             var icon_bf13041798013fb8a81e14e1e5717223 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_208bc8754b214050728de3836a3233d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_953d0f647004b616f470ce815a8d08e2 = $(`&lt;div id=&quot;html_953d0f647004b616f470ce815a8d08e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uganda&lt;/div&gt;`)[0];
#                 popup_208bc8754b214050728de3836a3233d7.setContent(html_953d0f647004b616f470ce815a8d08e2);
#
#
#
#         marker_fead99248fc4d055ca508a3e2dd4dded.bindPopup(popup_208bc8754b214050728de3836a3233d7)
#         ;
#
#
#
#
#                 marker_fead99248fc4d055ca508a3e2dd4dded.setIcon(icon_bf13041798013fb8a81e14e1e5717223);
#
#
#             var marker_008b229c71f45ed3b3c6a8d0d08d2f54 = L.marker(
#                 [-6.369, 34.8888],
#                 {
# }
#             ).addTo(map_658430d228264cbbb8d325a933a6f87c);
#
#
#             var icon_b6dc069d7a4fb6b864668c20f70cc14b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a1116d9ef0677680e16da5567069f22f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_946dfeee3112b8a390d90e12b97d401e = $(`&lt;div id=&quot;html_946dfeee3112b8a390d90e12b97d401e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tanzania&lt;/div&gt;`)[0];
#                 popup_a1116d9ef0677680e16da5567069f22f.setContent(html_946dfeee3112b8a390d90e12b97d401e);
#
#
#
#         marker_008b229c71f45ed3b3c6a8d0d08d2f54.bindPopup(popup_a1116d9ef0677680e16da5567069f22f)
#         ;
#
#
#
#
#                 marker_008b229c71f45ed3b3c6a8d0d08d2f54.setIcon(icon_b6dc069d7a4fb6b864668c20f70cc14b);
#
#
#             var marker_39697658e9e95a510b1b094e39cfda0d = L.marker(
#                 [44.0165, 21.0059],
#                 {
# }
#             ).addTo(map_658430d228264cbbb8d325a933a6f87c);
#
#
#             var icon_b7e3097e8519b9f22fa61269eec302c8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9c0000479b744316f0549b97dbba4dd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbaeebcc587ae72f680331d53e472077 = $(`&lt;div id=&quot;html_cbaeebcc587ae72f680331d53e472077&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Serbia&lt;/div&gt;`)[0];
#                 popup_9c0000479b744316f0549b97dbba4dd4.setContent(html_cbaeebcc587ae72f680331d53e472077);
#
#
#
#         marker_39697658e9e95a510b1b094e39cfda0d.bindPopup(popup_9c0000479b744316f0549b97dbba4dd4)
#         ;
#
#
#
#
#                 marker_39697658e9e95a510b1b094e39cfda0d.setIcon(icon_b7e3097e8519b9f22fa61269eec302c8);
#
#
#             var marker_e004602eca7a8d3fc018f8c9f14b3c9b = L.marker(
#                 [14.4974, -14.4524],
#                 {
# }
#             ).addTo(map_658430d228264cbbb8d325a933a6f87c);
#
#
#             var icon_83bf40ebc4d2826ae3b74096eb15c603 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quo

# %%
#test
