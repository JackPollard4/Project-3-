# %%
# Project-3-


import folium

# Define a dictionary with country names and their approximate latitude and longitude
country_coords = {
    "Uganda": [1.3733, 32.2903],
    "Tanzania": [-6.3690, 34.8888],
    "Serbia": [44.0165, 21.0059],
    "Senegal": [14.4974, -14.4524],
    "Panama": [8.5380, -80.7821],
    "Nigeria": [9.0820, 8.6753],
    "Mali": [17.5707, -3.9962],
    "Malawi": [-13.2543, 34.3015],
    "Guatemala": [15.7835, -90.2308],
    "Ghana": [7.9465, -1.0232],
    "Ethiopia": [9.1450, 40.4897]
}

# Create a map centered around Africa for better visibility
map_center = [10, 10]  
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the map
world_map



# Add USA coordinates to the dictionary
country_coords["USA"] = [37.0902, -95.7129]  # Approximate center of the USA

# Create a new map centered around Africa for better visibility
map_center = [10, 10]
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the updated map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba5f495f059c628bfd03d8471d06c2d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba5f495f059c628bfd03d8471d06c2d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba5f495f059c628bfd03d8471d06c2d8 = L.map(
#                 &quot;map_ba5f495f059c628bfd03d8471d06c2d8&quot;,
#                 {
#                     center: [10.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a65fa1e4e40744bb6ea24ae48c428bb1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a65fa1e4e40744bb6ea24ae48c428bb1.addTo(map_ba5f495f059c628bfd03d8471d06c2d8);
#
#
#             var marker_8017af5ddf20776a791469805aa79419 = L.marker(
#                 [1.3733, 32.2903],
#                 {
# }
#             ).addTo(map_ba5f495f059c628bfd03d8471d06c2d8);
#
#
#             var icon_8cd58e1b3d499e88cd7c0a07f666a0d7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_06ca48d7a212f312780180c5428cfee8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d15bdbd15bc3e54b8bf02f34a03c9c9 = $(`&lt;div id=&quot;html_9d15bdbd15bc3e54b8bf02f34a03c9c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uganda&lt;/div&gt;`)[0];
#                 popup_06ca48d7a212f312780180c5428cfee8.setContent(html_9d15bdbd15bc3e54b8bf02f34a03c9c9);
#
#
#
#         marker_8017af5ddf20776a791469805aa79419.bindPopup(popup_06ca48d7a212f312780180c5428cfee8)
#         ;
#
#
#
#
#                 marker_8017af5ddf20776a791469805aa79419.setIcon(icon_8cd58e1b3d499e88cd7c0a07f666a0d7);
#
#
#             var marker_d2bdfac1aa2c0baca826b266d192be0b = L.marker(
#                 [-6.369, 34.8888],
#                 {
# }
#             ).addTo(map_ba5f495f059c628bfd03d8471d06c2d8);
#
#
#             var icon_c3a605cd14256eb3fa453dada0d19de5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0f68d2453d2347e76ca3058480d68e98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13c5e64757e9b2ff17e49e00ea01cf92 = $(`&lt;div id=&quot;html_13c5e64757e9b2ff17e49e00ea01cf92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tanzania&lt;/div&gt;`)[0];
#                 popup_0f68d2453d2347e76ca3058480d68e98.setContent(html_13c5e64757e9b2ff17e49e00ea01cf92);
#
#
#
#         marker_d2bdfac1aa2c0baca826b266d192be0b.bindPopup(popup_0f68d2453d2347e76ca3058480d68e98)
#         ;
#
#
#
#
#                 marker_d2bdfac1aa2c0baca826b266d192be0b.setIcon(icon_c3a605cd14256eb3fa453dada0d19de5);
#
#
#             var marker_0752fc69220e4aef0135898c433b29d8 = L.marker(
#                 [44.0165, 21.0059],
#                 {
# }
#             ).addTo(map_ba5f495f059c628bfd03d8471d06c2d8);
#
#
#             var icon_3db8ea387777d07300c0c31e21f63708 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_58381fa207fae83163bcd945513357be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4de47aeb496f4b4bd91ecc64d571f669 = $(`&lt;div id=&quot;html_4de47aeb496f4b4bd91ecc64d571f669&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Serbia&lt;/div&gt;`)[0];
#                 popup_58381fa207fae83163bcd945513357be.setContent(html_4de47aeb496f4b4bd91ecc64d571f669);
#
#
#
#         marker_0752fc69220e4aef0135898c433b29d8.bindPopup(popup_58381fa207fae83163bcd945513357be)
#         ;
#
#
#
#
#                 marker_0752fc69220e4aef0135898c433b29d8.setIcon(icon_3db8ea387777d07300c0c31e21f63708);
#
#
#             var marker_7cbd55eb181e881f160518f946ff4bb5 = L.marker(
#                 [14.4974, -14.4524],
#                 {
# }
#             ).addTo(map_ba5f495f059c628bfd03d8471d06c2d8);
#
#
#             var icon_ef0f5629e91601f033291190fd600c03 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quo

# %%
#test
