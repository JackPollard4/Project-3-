# %%
# Project-3-


import folium

# Define a dictionary with country names and their approximate latitude and longitude
country_coords = {
    "Uganda": [1.3733, 32.2903],
    "Tanzania": [-6.3690, 34.8888],
    "Serbia": [44.0165, 21.0059],
    "Senegal": [14.4974, -14.4524],
    "Panama": [8.5380, -80.7821],
    "Nigeria": [9.0820, 8.6753],
    "Mali": [17.5707, -3.9962],
    "Malawi": [-13.2543, 34.3015],
    "Guatemala": [15.7835, -90.2308],
    "Ghana": [7.9465, -1.0232],
    "Ethiopia": [9.1450, 40.4897]
}

# Create a map centered around Africa for better visibility
map_center = [10, 10]  
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the map
world_map



# Add USA coordinates to the dictionary
country_coords["USA"] = [37.0902, -95.7129]  # Approximate center of the USA

# Create a new map centered around Africa for better visibility
map_center = [10, 10]
world_map = folium.Map(location=map_center, zoom_start=3)

# Add markers for each country
for country, coords in country_coords.items():
    folium.Marker(
        location=coords,
        popup=country,
        icon=folium.Icon(color="red", icon="info-sign")
    ).add_to(world_map)

# Display the updated map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_299f2fbe7a46c1a37c3d3f6be7d291fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_299f2fbe7a46c1a37c3d3f6be7d291fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_299f2fbe7a46c1a37c3d3f6be7d291fc = L.map(
#                 &quot;map_299f2fbe7a46c1a37c3d3f6be7d291fc&quot;,
#                 {
#                     center: [10.0, 10.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c948ed59138ef27ba1597788efc8eb16 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c948ed59138ef27ba1597788efc8eb16.addTo(map_299f2fbe7a46c1a37c3d3f6be7d291fc);
#
#
#             var marker_0ac6cd55b50163020bb315e72a27d1f3 = L.marker(
#                 [1.3733, 32.2903],
#                 {
# }
#             ).addTo(map_299f2fbe7a46c1a37c3d3f6be7d291fc);
#
#
#             var icon_746a19d45e09d95a0d8f459f4b5ca654 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7d366da707052cf1f8d97a961e1f1c28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2f3255876b39f8a822d993453765045 = $(`&lt;div id=&quot;html_b2f3255876b39f8a822d993453765045&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Uganda&lt;/div&gt;`)[0];
#                 popup_7d366da707052cf1f8d97a961e1f1c28.setContent(html_b2f3255876b39f8a822d993453765045);
#
#
#
#         marker_0ac6cd55b50163020bb315e72a27d1f3.bindPopup(popup_7d366da707052cf1f8d97a961e1f1c28)
#         ;
#
#
#
#
#                 marker_0ac6cd55b50163020bb315e72a27d1f3.setIcon(icon_746a19d45e09d95a0d8f459f4b5ca654);
#
#
#             var marker_bb39e9132155b0a8985d493715edaa9a = L.marker(
#                 [-6.369, 34.8888],
#                 {
# }
#             ).addTo(map_299f2fbe7a46c1a37c3d3f6be7d291fc);
#
#
#             var icon_368e0e842a59ba5a21fa2319d95a8b07 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8b03ccd5c0edcd1b82871eec95a45ff1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1579b63569f868c4dcb42a4de760814 = $(`&lt;div id=&quot;html_f1579b63569f868c4dcb42a4de760814&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tanzania&lt;/div&gt;`)[0];
#                 popup_8b03ccd5c0edcd1b82871eec95a45ff1.setContent(html_f1579b63569f868c4dcb42a4de760814);
#
#
#
#         marker_bb39e9132155b0a8985d493715edaa9a.bindPopup(popup_8b03ccd5c0edcd1b82871eec95a45ff1)
#         ;
#
#
#
#
#                 marker_bb39e9132155b0a8985d493715edaa9a.setIcon(icon_368e0e842a59ba5a21fa2319d95a8b07);
#
#
#             var marker_264ac4555f38ab82782e2847bab886cc = L.marker(
#                 [44.0165, 21.0059],
#                 {
# }
#             ).addTo(map_299f2fbe7a46c1a37c3d3f6be7d291fc);
#
#
#             var icon_ea47f4d67a91419e58ed1c96f2b1e66a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6f566a1444e93a0841eae89c335b79e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91964949b12ef4505fb47bb45d71b849 = $(`&lt;div id=&quot;html_91964949b12ef4505fb47bb45d71b849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Serbia&lt;/div&gt;`)[0];
#                 popup_6f566a1444e93a0841eae89c335b79e9.setContent(html_91964949b12ef4505fb47bb45d71b849);
#
#
#
#         marker_264ac4555f38ab82782e2847bab886cc.bindPopup(popup_6f566a1444e93a0841eae89c335b79e9)
#         ;
#
#
#
#
#                 marker_264ac4555f38ab82782e2847bab886cc.setIcon(icon_ea47f4d67a91419e58ed1c96f2b1e66a);
#
#
#             var marker_6b49e39dc25969c3d696f1f78053e8b6 = L.marker(
#                 [14.4974, -14.4524],
#                 {
# }
#             ).addTo(map_299f2fbe7a46c1a37c3d3f6be7d291fc);
#
#
#             var icon_615347b67a549aa7b3eefe75af25915c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quo
